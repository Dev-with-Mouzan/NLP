# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sentences = [
    'I love my dog',
    'I love my cat',
    'You love my dog!',
    'Do you think my dog is amazing?'
]

# %%
tok=Tokenizer()

# %%
tok.fit_on_texts(sentences)

# %%
tok.word_index
# Out:
# {'my': 1,
#  'love': 2,
#  'dog': 3,
#  'i': 4,
#  'you': 5,
#  'cat': 6,
#  'do': 7,
#  'think': 8,
#  'is': 9,
#  'amazing': 10}

# %%
tok.word_counts
# Out:
# OrderedDict([('i', 2),
#              ('love', 3),
#              ('my', 4),
#              ('dog', 3),
#              ('cat', 1),
#              ('you', 2),
#              ('do', 1),
#              ('think', 1),
#              ('is', 1),
#              ('amazing', 1)])

# %%
sequence=tok.texts_to_sequences(sentences)

# %%
sequence
# Out:
# [[4, 2, 1, 3], [4, 2, 1, 6], [5, 2, 1, 3], [7, 5, 8, 1, 3, 9, 10]]

# %%
padded=pad_sequences(sequence,padding='post')

# %%
padded
# Out:
# array([[ 4,  2,  1,  3,  0,  0,  0],
#        [ 4,  2,  1,  6,  0,  0,  0],
#        [ 5,  2,  1,  3,  0,  0,  0],
#        [ 7,  5,  8,  1,  3,  9, 10]], dtype=int32)
